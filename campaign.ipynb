# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv(r"Downloads/Campaign data 1.csv")
df2=pd.read_csv(r"Downloads/Campaign data 2.csv")

# %%
df1=pd.read_csv(r"Downloads/Campaign data 1.csv")
df2=pd.read_csv(r"Downloads/Campaign data 2.csv")

# %%
df=pd.merge(df1,df2)

# %%
df
# Out:
#               Date Data source               Campaign    Media Type  \
# 0       30-12-2019   Pinterest       Kicks campaign 2       Display
# 1       30-12-2019   Pinterest       Kicks campaign 2       Display
# 2       30-12-2019   Pinterest       Kicks campaign 2       Display
# 3       30-12-2019   Pinterest       Kicks campaign 2       Display
# 4       30-12-2019   Pinterest       Kicks campaign 2       Display
# ...            ...         ...                    ...           ...
# 123694  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123695  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123696  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123697  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123698  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value Message type  \
# ...

# %%
df.shape
# Out:
# (123699, 9)

# %%
df.columns
# Out:
# Index(['Date', 'Data source', 'Campaign', 'Media Type', 'City', 'Metric',
#        'Value', 'Message type', 'Model'],
#       dtype='object')

# %%
df.head()
# Out:
#          Date Data source          Campaign Media Type  \
# 0  30-12-2019   Pinterest  Kicks campaign 2    Display
# 1  30-12-2019   Pinterest  Kicks campaign 2    Display
# 2  30-12-2019   Pinterest  Kicks campaign 2    Display
# 3  30-12-2019   Pinterest  Kicks campaign 2    Display
# 4  30-12-2019   Pinterest  Kicks campaign 2    Display
#
#                        City       Metric  Value Message type  Model
# 0   Colorado Springs-Pueblo  Impressions    1.0  Near Market  Kicks
# 1   Colorado Springs-Pueblo   Media Cost    0.0  Near Market  Kicks
# 2   Colorado Springs-Pueblo       Clicks    0.0  Near Market  Kicks
# 3  Sacramnto-Stkton-Modesto  Impressions    1.0  Near Market  Kicks
# 4  Sacramnto-Stkton-Modesto   Media Cost    0.0  Near Market  Kicks

# %%
df.tail()
# Out:
#               Date Data source               Campaign    Media Type  \
# 123694  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123695  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123696  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123697  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123698  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value Message type  \
# 123694  Sacramento - Stockton - Modesto   Media Cost    136.94  Near Market
# 123695  Sacramento - Stockton - Modesto       Clicks     81.00  Near Market
# 123696               Dallas - Ft. Worth  Impressions  16579.00  Near Market
# 123697               Dallas - Ft. Worth   Media Cost    297.78  Near Market
# 123698               Dallas - Ft. Worth       Clicks    128.00  Near Market
#
#              Model
# 123694  Pathfinder
# 123695  Pathfinder
# 123696  Pathfinder
# ...

# %%
df.sample(10)
# Out:
#               Date Data source               Campaign    Media Type  \
# 8862    27-06-2020    Snapchat      Sentra campaign 1  Online Video
# 43811   01-12-2020    Snapchat       Rogue campaign 5  Online Video
# 40254   16-11-2020    Snapchat       Rogue campaign 5  Online Video
# 113803  19-09-2021    Snapchat  Pathfinder campaign 8  Online Video
# 84411   13-04-2021    Snapchat      Armada campaign 1       Display
# 54597   05-01-2021    Snapchat       Rogue campaign 1  Online Video
# 80780   29-03-2021   Pinterest           shop at home       Display
# 94302   09-08-2021    Snapchat  Pathfinder campaign 6  Online Video
# 100761  23-08-2021   Pinterest  Pathfinder campaign 2  Online Video
# 30226   19-10-2020   Pinterest      Armada campaign 2       Display
#
#                                        City       Metric      Value  \
# 8862        Raleigh - Durham (fayetteville)  Impressions     639.00
# 43811                           Kansas City       Clicks      51.00
# ...

# %%
df.dtypes
# Out:
# Date             object
# Data source      object
# Campaign         object
# Media Type       object
# City             object
# Metric           object
# Value           float64
# Message type     object
# Model            object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Date            0
# Data source     0
# Campaign        0
# Media Type      0
# City            0
# Metric          0
# Value           0
# Message type    0
# Model           0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#               Date Data source      Campaign Media Type  \
# 80807   29-03-2021   Pinterest  shop at home    Display
# 80858   29-03-2021   Pinterest  shop at home    Display
# 80907   29-03-2021   Pinterest  shop at home    Display
# 80908   29-03-2021   Pinterest  shop at home    Display
# 80909   29-03-2021   Pinterest  shop at home    Display
# ...            ...         ...           ...        ...
# 122584  27-09-2021   Pinterest  shop at home    Display
# 122585  27-09-2021   Pinterest  shop at home    Display
# 122586  27-09-2021   Pinterest  shop at home    Display
# 122587  27-09-2021   Pinterest  shop at home    Display
# 122588  27-09-2021   Pinterest  shop at home    Display
#
#                               City       Metric   Value   Message type  \
# 80807                        Utica       Clicks    3.00  Future Market
# 80858                        Utica       Clicks    3.00  Future Market
# 80907                        Utica  Impressions  750.00  Future Market
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#               Date Data source               Campaign    Media Type  \
# 0       30-12-2019   Pinterest       Kicks campaign 2       Display
# 1       30-12-2019   Pinterest       Kicks campaign 2       Display
# 2       30-12-2019   Pinterest       Kicks campaign 2       Display
# 3       30-12-2019   Pinterest       Kicks campaign 2       Display
# 4       30-12-2019   Pinterest       Kicks campaign 2       Display
# ...            ...         ...                    ...           ...
# 123694  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123695  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123696  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123697  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
# 123698  30-09-2021    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value Message type  \
# ...

# %%
df.dtypes
# Out:
# Date             object
# Data source      object
# Campaign         object
# Media Type       object
# City             object
# Metric           object
# Value           float64
# Message type     object
# Model            object
# dtype: object

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value Message type  \
# 0               Colorado Springs-Pueblo  Impressions      1.00  Near Market
# ...

# %%
df.dtypes
# Out:
# Date            datetime64[ns]
# Data source             object
# Campaign                object
# Media Type              object
# City                    object
# Metric                  object
# Value                  float64
# Message type            object
# Model                   object
# dtype: object

# %%
df.describe()
# Out:
#                                 Date         Value
# count                         122629  1.226290e+05
# mean   2021-02-09 02:36:48.749969920  6.999154e+03
# min              2019-12-30 00:00:00  0.000000e+00
# 25%              2020-10-21 00:00:00  6.340000e+00
# 50%              2021-01-30 00:00:00  7.600000e+01
# 75%              2021-08-05 00:00:00  1.156000e+03
# max              2021-09-30 00:00:00  1.627800e+06
# std                              NaN  3.411575e+04

# %%
df['Day']=df['Date'].dt.Day
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df['Day']=df['Date'].dt.Day
#
# AttributeError: 'DatetimeProperties' object has no attribute 'Day'

# %%
df
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value Message type  \
# 0               Colorado Springs-Pueblo  Impressions      1.00  Near Market
# ...

# %%
df['Day']=df['Date'].dt.Day
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df['Day']=df['Date'].dt.Day
#
# AttributeError: 'DatetimeProperties' object has no attribute 'Day'

# %%
df
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value Message type  \
# 0               Colorado Springs-Pueblo  Impressions      1.00  Near Market
# ...

# %%
df["month"]=df["Date"].dt.month

# %%
df
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value Message type  \
# 0               Colorado Springs-Pueblo  Impressions      1.00  Near Market
# ...

# %%
df["year"]=df["Date"].dt.year

# %%
df
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value Message type  \
# 0               Colorado Springs-Pueblo  Impressions      1.00  Near Market
# ...

# %%
df_impression=df[df['Metric']=="Impressions"]

# %%
df_impression
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 6      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 9      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 12     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 123684 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123687 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123690 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123693 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric    Value Message type  \
# 0               Colorado Springs-Pueblo  Impressions      1.0  Near Market
# ...

# %%
df_impression.groupby[("month")['value']].sum()).sort_values(ascending=False)[:5]
# Out:
#   Cell In[65], line 1
#     df_impression.groupby[("month")['value']].sum()).sort_values(ascending=False)[:5]
#                                                    ^
# SyntaxError: unmatched ')'

# %%
df_impression
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 6      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 9      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 12     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 123684 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123687 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123690 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123693 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric    Value Message type  \
# 0               Colorado Springs-Pueblo  Impressions      1.0  Near Market
# ...

# %%
df_impression.groupby('month')['Value'].sum().sort_values(ascending=False)[:5]
# Out:
# month
# 9     195438538.0
# 3     159488182.0
# 10    129386691.0
# 8     117299533.0
# 2      95672149.0
# Name: Value, dtype: float64

# %%
df['year'].value_counts()
# Out:
# year
# 2021    70270
# 2020    52338
# 2019       21
# Name: count, dtype: int64

# %%
df_impression.groupby(['month','year'])['Value'].sum().sort_values(ascending=False)[:5]
# Out:
# month  year
# 9      2021    165961494.0
# 10     2020    129386691.0
# 8      2021    110579025.0
# 3      2021    101719848.0
# 2      2020     61351689.0
# Name: Value, dtype: float64

# %%
df_impression.groupby(['month','Metric','year'])['Value'].sum().sort_values(ascending=False)[:5]
# Out:
# month  Metric       year
# 9      Impressions  2021    165961494.0
# 10     Impressions  2020    129386691.0
# 8      Impressions  2021    110579025.0
# 3      Impressions  2021    101719848.0
# 2      Impressions  2020     61351689.0
# Name: Value, dtype: float64

# %%
df_new=df_impression.groupby(['month','Metric','year'])['Value'].sum().sort_values(ascending=False)[:5].reset_index()

# %%
df_new
# Out:
#    month       Metric  year        Value
# 0      9  Impressions  2021  165961494.0
# 1     10  Impressions  2020  129386691.0
# 2      8  Impressions  2021  110579025.0
# 3      3  Impressions  2021  101719848.0
# 4      2  Impressions  2020   61351689.0

# %% [markdown]
# #2.	Which model has maximum impressions?

# %%
df
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value Message type  \
# 0               Colorado Springs-Pueblo  Impressions      1.00  Near Market
# ...

# %%
df_impression=df[df['Metric']=="Impressions"]

# %%
df_impression
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 6      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 9      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 12     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 123684 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123687 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123690 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123693 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric    Value Message type  \
# 0               Colorado Springs-Pueblo  Impressions      1.0  Near Market
# ...

# %%
df_impression.groupby(['Model','Metric'])['Value'].sum().sort_values(ascending=False)
# Out:
# Model        Metric
# Pathfinder   Impressions    275832034.0
# Armada       Impressions    175569709.0
# Rogue        Impressions    132109157.0
# Altima       Impressions     99823376.0
# Kicks        Impressions     95929225.0
# Sentra       Impressions     64176011.0
# Multi-Model  Impressions      4915930.0
# Name: Value, dtype: float64

# %%
df_impression.groupby(['Message type','Campaign','Metric'])[['Value']].sum().sort_values(by='Value')[:3]
# Out:
#                                                 Value
# Message type  Campaign          Metric
# Near Market   Kicks campaign 2  Impressions    1485.0
#               Kicks campaign 1  Impressions  120791.0
# Future Market Sentra campaign 2 Impressions  193569.0

# %%
df_impression.groupby(['Message type','Campaign','Metric'])[['Value']].sum().sort_values(by='Value')[:3].reset_index()
# Out:
#     Message type           Campaign       Metric     Value
# 0    Near Market   Kicks campaign 2  Impressions    1485.0
# 1    Near Market   Kicks campaign 1  Impressions  120791.0
# 2  Future Market  Sentra campaign 2  Impressions  193569.0

# %%
df_NearMarket=df[df['Message type']=="Near Market"]

# %%
df_NearMarket
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value Message type  \
# 0               Colorado Springs-Pueblo  Impressions      1.00  Near Market
# ...

# %%
df_FutureMarket=df[df['Message type']=="Future Market"]

# %%
df_FutureMarket
# Out:
#              Date Data source           Campaign    Media Type  \
# 3987   2020-03-12    Snapchat  Sentra campaign 2  Online Video
# 3988   2020-03-12    Snapchat  Sentra campaign 2  Online Video
# 3989   2020-03-12    Snapchat  Sentra campaign 2  Online Video
# 3990   2020-03-12    Snapchat  Sentra campaign 2  Online Video
# 3991   2020-03-12    Snapchat  Sentra campaign 2  Online Video
# ...           ...         ...                ...           ...
# 122569 2021-09-27   Pinterest       shop at home       Display
# 122570 2021-09-27   Pinterest       shop at home       Display
# 122574 2021-09-27   Pinterest       shop at home       Display
# 122575 2021-09-27   Pinterest       shop at home       Display
# 122576 2021-09-27   Pinterest       shop at home       Display
#
#                               City       Metric   Value   Message type  \
# 3987                       Memphis  Impressions  231.00  Future Market
# ...

# %%
ds3=df_NearMarket.groupby(['Message type','Campaign','Metric'])[['Value']].sum().sort_values(by='Value')[:3].reset_index()

# %%
ds4=df_FutureMarket.groupby(['Message type','Campaign','Metric'])[['Value']].sum().sort_values(by='Value')[:3].reset_index()

# %%
ds3
# Out:
#   Message type           Campaign      Metric  Value
# 0  Near Market   Kicks campaign 2  Media Cost    0.0
# 1  Near Market   Kicks campaign 1  Media Cost    0.0
# 2  Near Market  Armada campaign 1      Clicks    0.0

# %%
ds4
# Out:
#     Message type           Campaign      Metric    Value
# 0  Future Market  Sentra campaign 2  Media Cost   719.29
# 1  Future Market  Sentra campaign 4      Clicks  1380.00
# 2  Future Market  Sentra campaign 2      Clicks  1626.00

# %%
df5=pd.merge(ds3,ds4)

# %%
df5
# Out:
# Empty DataFrame
# Columns: [Message type, Campaign, Metric, Value]
# Index: []

# %%
df.groupby(['Media Type', 'month'])[['Value']].mean()
# Out:
#                            Value
# Media Type   month
# Display      1          8.085271
#              2      18101.660471
#              3      17178.844665
#              4       2023.553793
#              5          6.983985
#              6          8.735784
#              7          6.300473
#              8          4.725375
#              9      11478.233773
#              10         8.846123
#              11         5.127946
#              12         6.459459
# Online Video 1       4921.104459
#              2       7744.503079
#              3       7370.839439
#              4       6907.717932
#              5         15.694530
#              6        283.990234
#              7       1055.305907
#              8       7707.028095
#              9       9012.731701
#              10      7949.702510
#              11      4985.346979
#              12      6989.815205

# %%
df
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value Message type  \
# 0               Colorado Springs-Pueblo  Impressions      1.00  Near Market
# ...

# %%
df_impressions=df[df['Metric']=='Impressions']

# %%
df_impressions
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 6      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 9      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 12     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 123684 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123687 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123690 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123693 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric    Value Message type  \
# 0               Colorado Springs-Pueblo  Impressions      1.0  Near Market
# ...

# %%
df_clicks=df[df["Metric"]=='Clicks']

# %%
df_clicks
# Out:
#              Date Data source               Campaign    Media Type  \
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 5      2019-12-30   Pinterest       Kicks campaign 2       Display
# 8      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 11     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 14     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 123686 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123689 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123692 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City  Metric  Value Message type  \
# 2               Colorado Springs-Pueblo  Clicks    0.0  Near Market
# ...

# %%
df_impressions.groupby(['Campaign','Metric'])[['Value']].sum().sort_values(by='Value')
# Out:
#                                          Value
# Campaign              Metric
# Kicks campaign 2      Impressions       1485.0
# Kicks campaign 1      Impressions     120791.0
# Sentra campaign 2     Impressions     193569.0
# Sentra campaign 4     Impressions     196841.0
# Altima campaign 4     Impressions     380995.0
# Sentra campaign 10    Impressions     859107.0
# Sentra campaign 13    Impressions     922310.0
# Sentra campaign 17    Impressions    1053431.0
# Sentra campaign 5     Impressions    1137379.0
# Altima campaign 5     Impressions    1176593.0
# Sentra campaign 8     Impressions    1356458.0
# Altima campaign 6     Impressions    1533773.0
# Sentra campaign 24    Impressions    1555632.0
# Sentra campaign 16    Impressions    1619686.0
# Sentra campaign 25    Impressions    1704259.0
# Armada campaign 1     Impressions    1799471.0
# Sentra campaign 23    Impressions    1870596.0
# Kicks campaign 5      Impressions    1981485.0
# ...

# %%
x1=df_impressions.groupby(['Campaign','Metric'])[['Value']].sum().sort_values(by='Value')[0:1].reset_index()

# %%
x2=df_clicks.groupby(['Campaign','Metric'])[['Value']].sum().sort_values(by='Value')[0:1].reset_index()

# %%
x1
# Out:
#            Campaign       Metric   Value
# 0  Kicks campaign 2  Impressions  1485.0

# %%
x2
# Out:
#             Campaign  Metric  Value
# 0  Armada campaign 1  Clicks    0.0
